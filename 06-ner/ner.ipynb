# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

text = """Kiran want to know the famous foods in each state of India. So, he opened Google and search for this question. Google showed that
in Delhi it is Chaat, in Gujarat it is Dal Dhokli, in Tamilnadu it is Pongal, in Andhrapradesh it is Biryani, in Assam it is Papaya Khar,
in Bihar it is Litti Chowkha and so on for all other states"""

doc = nlp(text)

for ent in doc.ents:
  print(ent, "|", ent.label_, "|", spacy.explain(ent.label_))
# Out:
# Kiran | GPE | Countries, cities, states
# India | GPE | Countries, cities, states
# Google | ORG | Companies, agencies, institutions, etc.
# Google | ORG | Companies, agencies, institutions, etc.
# Delhi | GPE | Countries, cities, states
# Chaat | ORG | Companies, agencies, institutions, etc.
# Gujarat | GPE | Countries, cities, states
# Dal Dhokli | PERSON | People, including fictional
# Tamilnadu | GPE | Countries, cities, states
# Pongal | PERSON | People, including fictional
# Andhrapradesh | GPE | Countries, cities, states
# Biryani | PERSON | People, including fictional
# Assam | GPE | Countries, cities, states
# Papaya Khar | PERSON | People, including fictional
# Bihar | GPE | Countries, cities, states
# Litti Chowkha | ORG | Companies, agencies, institutions, etc.

# %%
from spacy.tokens import Span

s1 = Span(doc, 0,1, 'PERSON')

doc.set_ents([s1], default='unmodified')

# %%
for ent in doc.ents:
  print(ent, "|", ent.label_, "|", spacy.explain(ent.label_))
# Out:
# Kiran | PERSON | People, including fictional
# India | GPE | Countries, cities, states
# Google | ORG | Companies, agencies, institutions, etc.
# Google | ORG | Companies, agencies, institutions, etc.
# Delhi | GPE | Countries, cities, states
# Chaat | ORG | Companies, agencies, institutions, etc.
# Gujarat | GPE | Countries, cities, states
# Dal Dhokli | PERSON | People, including fictional
# Tamilnadu | GPE | Countries, cities, states
# Pongal | PERSON | People, including fictional
# Andhrapradesh | GPE | Countries, cities, states
# Biryani | PERSON | People, including fictional
# Assam | GPE | Countries, cities, states
# Papaya Khar | PERSON | People, including fictional
# Bihar | GPE | Countries, cities, states
# Litti Chowkha | ORG | Companies, agencies, institutions, etc.

# %%
doc[65]
# Out:
# Litti

# %%
index = [[32,33], [38,40], [45,46], [51,52], [57,59], [65, 67]]

spans = []
for start, end in index:
  spans.append(Span(doc, start, end, 'FOOD'))

doc.set_ents(spans, default='unmodified')

# %%
geographical = []
for ent in doc.ents:
  if ent.label_ == 'GPE':
    geographical.append(ent)
  print(ent, "|", ent.label_, "|", spacy.explain(ent.label_))
# Out:
# Kiran | PERSON | People, including fictional
# India | GPE | Countries, cities, states
# Google | ORG | Companies, agencies, institutions, etc.
# Google | ORG | Companies, agencies, institutions, etc.
# Delhi | GPE | Countries, cities, states
# Chaat | FOOD | None
# Gujarat | GPE | Countries, cities, states
# Dal Dhokli | FOOD | None
# Tamilnadu | GPE | Countries, cities, states
# Pongal | FOOD | None
# Andhrapradesh | GPE | Countries, cities, states
# Biryani | FOOD | None
# Assam | GPE | Countries, cities, states
# Papaya Khar | FOOD | None
# Bihar | GPE | Countries, cities, states
# Litti Chowkha | FOOD | None
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\spacy\glossary.py:20: UserWarning: [W118] Term 'FOOD' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))

# %%
geographical
# Out:
# [India, Delhi, Gujarat, Tamilnadu, Andhrapradesh, Assam, Bihar]

# %%
len(geographical)
# Out:
# 7

# %%
text2 = """Sachin Tendulkar was born on 24 April 1973, Virat Kholi was born on 5 November 1988, Dhoni was born on 7 July 1981
and finally Ricky ponting was born on 19 December 1974."""

doc2 = nlp(text2)

birth_dates = []
for ent in doc2.ents:
  if ent.label_ == 'DATE':
    birth_dates.append(ent)
  print(ent, "|", ent.label_, "|", spacy.explain(ent.label_))
# Out:
# Sachin Tendulkar | PERSON | People, including fictional
# 24 April 1973 | DATE | Absolute or relative dates or periods
# Virat Kholi | ORG | Companies, agencies, institutions, etc.
# 5 November 1988 | DATE | Absolute or relative dates or periods
# Dhoni | PERSON | People, including fictional
# 7 July 1981 | DATE | Absolute or relative dates or periods
# Ricky | PERSON | People, including fictional
# 19 December 1974 | DATE | Absolute or relative dates or periods

# %%
birth_dates
# Out:
# [24 April 1973, 5 November 1988, 7 July 1981, 19 December 1974]

# %%
len(birth_dates)
# Out:
# 4
